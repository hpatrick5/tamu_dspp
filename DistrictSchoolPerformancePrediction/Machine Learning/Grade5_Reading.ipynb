# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ##Linear Regression

# %%
df = pd.read_csv("grade5_iter1_mean_impute_onehot_read.csv")

# %%
df
# Out:
#     ID  special_ed_indicator  lep_First Year of Monitoring  lep_LEP  \
# 0    0                     1                             0        1
# 1    1                     0                             0        0
# 2    2                     0                             0        0
# 3    3                     0                             0        0
# 4    4                     0                             0        0
# ..  ..                   ...                           ...      ...
# 95  95                     0                             0        0
# 96  96                     0                             0        1
# 97  97                     0                             0        1
# 98  98                     0                             0        0
# 99  99                     1                             0        0
#
#     lep_Other 0n-LEP Student  lep_Second Year of Monitoring  ethnicity_Asian  \
# 0                          0                              0                0
# 1                          1                              0                0
# 2                          1                              0                0
# 3                          1                              0                0
# 4                          1                              0                0
# ..                       ...                            ...              ...
# 95                         1                              0                0
# 96                         0                              0                0
# 97                         0                              0                0
# 98                         1                              0                0
# 99                         1                              0                0
#
#     ethnicity_Black/African American  ethnicity_Hispanic  percent_score_p  \
# 0                                  0                   1             0.33
# 1                                  1                   0             0.64
# 2                                  0                   1             0.78
# 3                                  1                   0             0.61
# 4                                  1                   0             0.22
# ..                               ...                 ...              ...
# 95                                 1                   0             0.72
# 96                                 0                   1             0.67
# 97                                 0                   1             0.33
# 98                                 1                   0             0.71
# 99                                 1                   0             0.24
#
#     percent_score_m1  percent_score_m2  percent_score_f
# 0               0.47              0.42             0.53
# 1               0.50              0.74             0.74
# 2               0.55              0.66             0.82
# 3               0.58              0.66             0.61
# 4               0.29              0.45             0.50
# ..               ...               ...              ...
# 95              0.68              0.76             0.82
# 96              0.68              0.66             0.71
# 97              0.32              0.34             0.66
# 98              0.79              0.63             0.87
# 99              0.24              0.24             0.21
#
# [100 rows x 13 columns]

# %%
#not including dependent variable (i.e. final STARR test in last column)
X = df.iloc[:, 1:12]
y = df['percent_score_f']

# %%
X
# Out:
#     special_ed_indicator  lep_First Year of Monitoring  lep_LEP  \
# 0                      1                             0        1
# 1                      0                             0        0
# 2                      0                             0        0
# 3                      0                             0        0
# 4                      0                             0        0
# ..                   ...                           ...      ...
# 95                     0                             0        0
# 96                     0                             0        1
# 97                     0                             0        1
# 98                     0                             0        0
# 99                     1                             0        0
#
#     lep_Other 0n-LEP Student  lep_Second Year of Monitoring  ethnicity_Asian  \
# 0                          0                              0                0
# 1                          1                              0                0
# 2                          1                              0                0
# 3                          1                              0                0
# 4                          1                              0                0
# ..                       ...                            ...              ...
# 95                         1                              0                0
# 96                         0                              0                0
# 97                         0                              0                0
# 98                         1                              0                0
# 99                         1                              0                0
#
#     ethnicity_Black/African American  ethnicity_Hispanic  percent_score_p  \
# 0                                  0                   1             0.33
# 1                                  1                   0             0.64
# 2                                  0                   1             0.78
# 3                                  1                   0             0.61
# 4                                  1                   0             0.22
# ..                               ...                 ...              ...
# 95                                 1                   0             0.72
# 96                                 0                   1             0.67
# 97                                 0                   1             0.33
# 98                                 1                   0             0.71
# 99                                 1                   0             0.24
#
#     percent_score_m1  percent_score_m2
# 0               0.47              0.42
# 1               0.50              0.74
# 2               0.55              0.66
# 3               0.58              0.66
# 4               0.29              0.45
# ..               ...               ...
# 95              0.68              0.76
# 96              0.68              0.66
# 97              0.32              0.34
# 98              0.79              0.63
# 99              0.24              0.24
#
# [100 rows x 11 columns]

# %%
y
# Out:
# 0     0.53
# 1     0.74
# 2     0.82
# 3     0.61
# 4     0.50
#       ...
# 95    0.82
# 96    0.71
# 97    0.66
# 98    0.87
# 99    0.21
# Name: percent_score_f, Length: 100, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 10)

# %%
X_train
# Out:
#     special_ed_indicator  lep_First Year of Monitoring  lep_LEP  \
# 90                     0                             0        0
# 70                     0                             0        0
# 50                     0                             0        0
# 44                     0                             0        1
# 76                     0                             0        0
# ..                   ...                           ...      ...
# 89                     0                             0        0
# 28                     0                             0        0
# 64                     0                             0        1
# 15                     0                             0        0
# 9                      0                             0        0
#
#     lep_Other 0n-LEP Student  lep_Second Year of Monitoring  ethnicity_Asian  \
# 90                         1                              0                0
# 70                         0                              1                0
# 50                         1                              0                0
# 44                         0                              0                0
# 76                         1                              0                0
# ..                       ...                            ...              ...
# 89                         1                              0                0
# 28                         1                              0                0
# 64                         0                              0                0
# 15                         0                              1                0
# 9                          1                              0                0
#
#     ethnicity_Black/African American  ethnicity_Hispanic  percent_score_p  \
# 90                                 1                   0            0.265
# 70                                 0                   1            0.670
# 50                                 0                   1            0.670
# 44                                 0                   1            0.640
# 76                                 1                   0            0.670
# ..                               ...                 ...              ...
# 89                                 0                   1            0.840
# 28                                 0                   1            0.720
# 64                                 0                   1            0.420
# 15                                 0                   1            0.940
# 9                                  1                   0            0.780
#
#     percent_score_m1  percent_score_m2
# 90              0.21              0.32
# 70              0.63              0.50
# 50              0.71              0.76
# 44              0.37              0.47
# 76              0.50              0.58
# ..               ...               ...
# 89              0.84              0.84
# 28              0.50              0.76
# 64              0.58              0.42
# 15              0.95              0.87
# 9               0.77              0.76
#
# [80 rows x 11 columns]

# %%
X_test
# Out:
#     special_ed_indicator  lep_First Year of Monitoring  lep_LEP  \
# 19                     0                             0        1
# 14                     0                             0        1
# 43                     0                             0        0
# 37                     0                             0        0
# 66                     0                             0        0
# 3                      0                             0        0
# 79                     0                             0        0
# 41                     0                             0        0
# 38                     0                             0        0
# 68                     0                             0        0
# 2                      0                             0        0
# 1                      0                             0        0
# 60                     0                             0        0
# 53                     0                             0        0
# 95                     0                             0        0
# 74                     0                             0        0
# 92                     0                             0        0
# 26                     0                             0        1
# 59                     0                             0        0
# 46                     0                             0        1
#
#     lep_Other 0n-LEP Student  lep_Second Year of Monitoring  ethnicity_Asian  \
# 19                         0                              0                0
# 14                         0                              0                0
# 43                         1                              0                0
# 37                         1                              0                0
# 66                         1                              0                0
# 3                          1                              0                0
# 79                         1                              0                0
# 41                         1                              0                0
# 38                         1                              0                0
# 68                         1                              0                0
# 2                          1                              0                0
# 1                          1                              0                0
# 60                         1                              0                0
# 53                         0                              1                1
# 95                         1                              0                0
# 74                         0                              1                1
# 92                         0                              1                0
# 26                         0                              0                0
# 59                         1                              0                0
# 46                         0                              0                0
#
#     ethnicity_Black/African American  ethnicity_Hispanic  percent_score_p  \
# 19                                 0                   1            0.890
# 14                                 0                   1            0.560
# 43                                 0                   1            0.810
# 37                                 1                   0            0.670
# 66                                 1                   0            0.440
# 3                                  1                   0            0.610
# 79                                 1                   0            0.805
# 41                                 1                   0            0.500
# 38                                 0                   1            0.890
# 68                                 0                   1            0.720
# 2                                  0                   1            0.780
# 1                                  1                   0            0.640
# 60                                 0                   1            0.690
# 53                                 0                   0            0.780
# 95                                 1                   0            0.720
# 74                                 0                   0            0.890
# 92                                 0                   1            0.555
# 26                                 0                   1            0.500
# 59                                 0                   1            0.920
# 46                                 0                   1            0.470
#
#     percent_score_m1  percent_score_m2
# 19              0.89              0.82
# 14              0.39              0.21
# 43              0.68              0.76
# 37              0.84              0.63
# 66              0.29              0.39
# 3               0.58              0.66
# 79              0.74              0.87
# 41              0.71              0.58
# 38              0.76              0.87
# 68              0.76              0.84
# 2               0.55              0.66
# 1               0.50              0.74
# 60              0.82              0.95
# 53              0.89              0.87
# 95              0.68              0.76
# 74              0.79              1.00
# 92              0.58              0.53
# 26              0.46              0.42
# 59              1.00              0.89
# 46              0.45              0.37

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

# %%
clf.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = clf.predict(X_test)

# %%
clf.score(X_test, y_test)
# Out:
# 0.7761622382285331

# %%
df1 = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df1
# Out:
#     Actual  Predicted
# 19    0.95   0.916311
# 14    0.47   0.465731
# 43    0.76   0.819505
# 37    0.82   0.792588
# 66    0.58   0.468582
# 3     0.61   0.697003
# 79    0.71   0.855727
# 41    0.79   0.706688
# 38    0.92   0.898918
# 68    0.87   0.870590
# 2     0.82   0.729534
# 1     0.74   0.698486
# 60    0.89   0.931064
# 53    0.89   0.881363
# 95    0.82   0.783534
# 74    0.82   0.901610
# 92    0.53   0.668958
# 26    0.58   0.563689
# 59    0.95   1.002056
# 46    0.55   0.538428

# %%
df3 = pd.concat([df1,X_test], axis=1)

# %%
df3
# Out:
#     Actual  Predicted  special_ed_indicator  lep_First Year of Monitoring  \
# 19    0.95   0.916311                     0                             0
# 14    0.47   0.465731                     0                             0
# 43    0.76   0.819505                     0                             0
# 37    0.82   0.792588                     0                             0
# 66    0.58   0.468582                     0                             0
# 3     0.61   0.697003                     0                             0
# 79    0.71   0.855727                     0                             0
# 41    0.79   0.706688                     0                             0
# 38    0.92   0.898918                     0                             0
# 68    0.87   0.870590                     0                             0
# 2     0.82   0.729534                     0                             0
# 1     0.74   0.698486                     0                             0
# 60    0.89   0.931064                     0                             0
# 53    0.89   0.881363                     0                             0
# 95    0.82   0.783534                     0                             0
# 74    0.82   0.901610                     0                             0
# 92    0.53   0.668958                     0                             0
# 26    0.58   0.563689                     0                             0
# 59    0.95   1.002056                     0                             0
# 46    0.55   0.538428                     0                             0
#
#     lep_LEP  lep_Other 0n-LEP Student  lep_Second Year of Monitoring  \
# 19        1                         0                              0
# 14        1                         0                              0
# 43        0                         1                              0
# 37        0                         1                              0
# 66        0                         1                              0
# 3         0                         1                              0
# 79        0                         1                              0
# 41        0                         1                              0
# 38        0                         1                              0
# 68        0                         1                              0
# 2         0                         1                              0
# 1         0                         1                              0
# 60        0                         1                              0
# 53        0                         0                              1
# 95        0                         1                              0
# 74        0                         0                              1
# 92        0                         0                              1
# 26        1                         0                              0
# 59        0                         1                              0
# 46        1                         0                              0
#
#     ethnicity_Asian  ethnicity_Black/African American  ethnicity_Hispanic  \
# 19                0                                 0                   1
# 14                0                                 0                   1
# 43                0                                 0                   1
# 37                0                                 1                   0
# 66                0                                 1                   0
# 3                 0                                 1                   0
# 79                0                                 1                   0
# 41                0                                 1                   0
# 38                0                                 0                   1
# 68                0                                 0                   1
# 2                 0                                 0                   1
# 1                 0                                 1                   0
# 60                0                                 0                   1
# 53                1                                 0                   0
# 95                0                                 1                   0
# 74                1                                 0                   0
# 92                0                                 0                   1
# 26                0                                 0                   1
# 59                0                                 0                   1
# 46                0                                 0                   1
#
#     percent_score_p  percent_score_m1  percent_score_m2
# 19            0.890              0.89              0.82
# 14            0.560              0.39              0.21
# 43            0.810              0.68              0.76
# 37            0.670              0.84              0.63
# 66            0.440              0.29              0.39
# 3             0.610              0.58              0.66
# 79            0.805              0.74              0.87
# 41            0.500              0.71              0.58
# 38            0.890              0.76              0.87
# 68            0.720              0.76              0.84
# 2             0.780              0.55              0.66
# 1             0.640              0.50              0.74
# 60            0.690              0.82              0.95
# 53            0.780              0.89              0.87
# 95            0.720              0.68              0.76
# 74            0.890              0.79              1.00
# 92            0.555              0.58              0.53
# 26            0.500              0.46              0.42
# 59            0.920              1.00              0.89
# 46            0.470              0.45              0.37

# %%
df3.to_csv(r'/Users/sukanyasravasti/LR_Reading_Grade5.csv', index = False)

# %%
df3['abs_diff'] = abs(df3['Actual'] - df3['Predicted'])

# %%
df3
# Out:
#     Actual  Predicted  special_ed_indicator  lep_First Year of Monitoring  \
# 19    0.95   0.916311                     0                             0
# 14    0.47   0.465731                     0                             0
# 43    0.76   0.819505                     0                             0
# 37    0.82   0.792588                     0                             0
# 66    0.58   0.468582                     0                             0
# 3     0.61   0.697003                     0                             0
# 79    0.71   0.855727                     0                             0
# 41    0.79   0.706688                     0                             0
# 38    0.92   0.898918                     0                             0
# 68    0.87   0.870590                     0                             0
# 2     0.82   0.729534                     0                             0
# 1     0.74   0.698486                     0                             0
# 60    0.89   0.931064                     0                             0
# 53    0.89   0.881363                     0                             0
# 95    0.82   0.783534                     0                             0
# 74    0.82   0.901610                     0                             0
# 92    0.53   0.668958                     0                             0
# 26    0.58   0.563689                     0                             0
# 59    0.95   1.002056                     0                             0
# 46    0.55   0.538428                     0                             0
#
#     lep_LEP  lep_Other 0n-LEP Student  lep_Second Year of Monitoring  \
# 19        1                         0                              0
# 14        1                         0                              0
# 43        0                         1                              0
# 37        0                         1                              0
# 66        0                         1                              0
# 3         0                         1                              0
# 79        0                         1                              0
# 41        0                         1                              0
# 38        0                         1                              0
# 68        0                         1                              0
# 2         0                         1                              0
# 1         0                         1                              0
# 60        0                         1                              0
# 53        0                         0                              1
# 95        0                         1                              0
# 74        0                         0                              1
# 92        0                         0                              1
# 26        1                         0                              0
# 59        0                         1                              0
# 46        1                         0                              0
#
#     ethnicity_Asian  ethnicity_Black/African American  ethnicity_Hispanic  \
# 19                0                                 0                   1
# 14                0                                 0                   1
# 43                0                                 0                   1
# 37                0                                 1                   0
# 66                0                                 1                   0
# 3                 0                                 1                   0
# 79                0                                 1                   0
# 41                0                                 1                   0
# 38                0                                 0                   1
# 68                0                                 0                   1
# 2                 0                                 0                   1
# 1                 0                                 1                   0
# 60                0                                 0                   1
# 53                1                                 0                   0
# 95                0                                 1                   0
# 74                1                                 0                   0
# 92                0                                 0                   1
# 26                0                                 0                   1
# 59                0                                 0                   1
# 46                0                                 0                   1
#
#     percent_score_p  percent_score_m1  percent_score_m2  abs_diff
# 19            0.890              0.89              0.82  0.033689
# 14            0.560              0.39              0.21  0.004269
# 43            0.810              0.68              0.76  0.059505
# 37            0.670              0.84              0.63  0.027412
# 66            0.440              0.29              0.39  0.111418
# 3             0.610              0.58              0.66  0.087003
# 79            0.805              0.74              0.87  0.145727
# 41            0.500              0.71              0.58  0.083312
# 38            0.890              0.76              0.87  0.021082
# 68            0.720              0.76              0.84  0.000590
# 2             0.780              0.55              0.66  0.090466
# 1             0.640              0.50              0.74  0.041514
# 60            0.690              0.82              0.95  0.041064
# 53            0.780              0.89              0.87  0.008637
# 95            0.720              0.68              0.76  0.036466
# 74            0.890              0.79              1.00  0.081610
# 92            0.555              0.58              0.53  0.138958
# 26            0.500              0.46              0.42  0.016311
# 59            0.920              1.00              0.89  0.052056
# 46            0.470              0.45              0.37  0.011572

# %%
df3.hist(column = 'abs_diff')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1173e61c0>]],
#       dtype=object)

# %% [markdown]
# ##Random Forest

# %%
df_rf = pd.read_csv("grade5_iter1_mean_impute_onehot_read.csv")

# %%
drop_indices = np.random.choice(df_rf.index, 10, replace=False)
df_rf_test = df_rf.loc[drop_indices]
df_rf = df_rf.drop(drop_indices)

# %%
X = df_rf.iloc[:, 0:12]
y = df_rf['percent_score_f']

# %%
df_rf
# Out:
#     ID  special_ed_indicator  ...  percent_score_m2  percent_score_f
# 0    0                     1  ...              0.42             0.53
# 1    1                     0  ...              0.74             0.74
# 2    2                     0  ...              0.66             0.82
# 3    3                     0  ...              0.66             0.61
# 4    4                     0  ...              0.45             0.50
# ..  ..                   ...  ...               ...              ...
# 95  95                     0  ...              0.76             0.82
# 96  96                     0  ...              0.66             0.71
# 97  97                     0  ...              0.34             0.66
# 98  98                     0  ...              0.63             0.87
# 99  99                     1  ...              0.24             0.21
#
# [90 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X,y, test_size = 10, random_state = 10)

# %%
X_train,X_valid
# Out:
# (    ID  special_ed_indicator  ...  percent_score_m1  percent_score_m2
#  69  69                     0  ...              0.58              0.61
#  71  71                     0  ...              0.66              0.79
#  55  55                     0  ...              0.66              0.71
#  67  67                     0  ...              0.74              0.87
#  91  91                     1  ...              0.34              0.58
#  ..  ..                   ...  ...               ...               ...
#  34  34                     1  ...              0.18              0.26
#  33  33                     0  ...              0.53              0.37
#  72  72                     0  ...              0.55              0.63
#  16  16                     0  ...              0.68              0.84
#  10  10                     0  ...              0.47              0.55
#
#  [80 rows x 12 columns],
#      ID  special_ed_indicator  ...  percent_score_m1  percent_score_m2
#  85  85                     0  ...              0.50              0.76
#  31  31                     0  ...              0.97              1.00
#  3    3                     0  ...              0.58              0.66
#  40  40                     0  ...              0.92              0.95
#  21  21                     0  ...              0.32              0.53
#  15  15                     0  ...              0.95              0.87
#  42  42                     0  ...              0.84              0.79
#  77  77                     1  ...              0.47              0.53
#  43  43                     0  ...              0.68              0.76
#  25  25                     1  ...              0.24              0.37
#
#  [10 rows x 12 columns])

# %%
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
from numpy import mean
from numpy import std

# %%
model = RandomForestRegressor(random_state=1)

# %%
cv = LeaveOneOut()

# %%
scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)

# %%
scores = abs(scores)
len(scores)
# Out:
# 90

# %%
print('MAE: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# MAE: 0.080 (0.057)

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
random_grid = { 'bootstrap': [True, False],
 'max_depth': [5,10,15],
 'max_features': ['auto', 'sqrt'],
 'min_samples_leaf': [1, 2, 4],
 'min_samples_split': [2, 5, 10],
 'n_estimators': [20,40,60,80]}

# %%
rf_random = RandomizedSearchCV(estimator = model, param_distributions = random_grid, n_iter = 10, cv = cv, verbose=2, random_state=42, n_jobs = -1)

# %%
rf_random.fit(X, y)
# Out:
# Fitting 90 folds for each of 10 candidates, totalling 900 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed:   29.5s
# [Parallel(n_jobs=-1)]: Done 900 out of 900 | elapsed:   49.1s finished
# RandomizedSearchCV(cv=LeaveOneOut(), error_score=nan,
#                    estimator=RandomForestRegressor(bootstrap=True,
#                                                    ccp_alpha=0.0,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
#                                                    min_samples_split=2,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=100,
#                                                    n_jobs=None, oo...
#                                                    random_state=1, verbose=0,
#                                                    warm_start=False),
#                    iid='deprecated', n_iter=10, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [5, 10, 15],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [20, 40, 60, 80]},
#                    pre_dispatch='2*n_jobs', random_state=42, refit=True,
#                    return_train_score=False, scoring=None, verbose=2)

# %%
rf_random.best_params_
# Out:
# {'bootstrap': False,
#  'max_depth': 15,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 4,
#  'min_samples_split': 5,
#  'n_estimators': 20}

# %%
df_rf_test.iloc[:,0:12]
# Out:
#     ID  special_ed_indicator  ...  percent_score_m1  percent_score_m2
# 68  68                     0  ...              0.76              0.84
# 20  20                     0  ...              0.82              0.84
# 22  22                     0  ...              0.74              0.66
# 24  24                     0  ...              0.37              0.53
# 92  92                     0  ...              0.58              0.53
# 27  27                     0  ...              0.53              0.47
# 52  52                     0  ...              0.68              0.82
# 75  75                     0  ...              0.84              0.84
# 5    5                     0  ...              0.50              0.61
# 54  54                     0  ...              0.37              0.68
#
# [10 rows x 12 columns]

# %%
predictions = rf_random.predict(df_rf_test.iloc[:,0:12])
predictions
errors = abs(predictions - df_rf_test.iloc[:,12])
errors
# Out:
# 68    0.037486
# 20    0.090619
# 22    0.030874
# 24    0.099612
# 92    0.085303
# 27    0.039611
# 52    0.062100
# 75    0.069551
# 5     0.190760
# 54    0.000677
# Name: percent_score_f, dtype: float64
